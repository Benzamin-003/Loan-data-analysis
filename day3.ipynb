# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('loan_data.csv')

df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
sns.countplot(data= df, x='previous_loan_defaults_on_file', hue = 'loan_status')
# Out:
# <Axes: xlabel='previous_loan_defaults_on_file', ylabel='count'>

# %%
df['previous_loan_defaults_on_file'] = df['previous_loan_defaults_on_file'].replace({'Yes':1, 'No':0})
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_24500\1399509820.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['previous_loan_defaults_on_file'] = df['previous_loan_defaults_on_file'].replace({'Yes':1, 'No':0})

# %% [markdown]
# # Section 1: Basic Exploratory Data Analysis (EDA)

# %% [markdown]
# # 1. What is the shape of dataset? How many rows and columns are there?

# %% [markdown]
#  The shape of dataset is rectangle.
#  There are 45000 rows and 14 columns.

# %% [markdown]
# # 2. Check for missing values.

# %% [markdown]
#  There are no any missing values.

# %% [markdown]
# # 3.What is the datatype of each column? Which ones are categorical and which ones are numerical?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  float64
#  1   person_gender                   45000 non-null  object
#  2   person_education                45000 non-null  object
#  3   person_income                   45000 non-null  float64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  object
#  6   loan_amnt                       45000 non-null  float64
#  7   loan_intent                     45000 non-null  object
#  8   loan_int_rate                   45000 non-null  float64
#  9   loan_percent_income             45000 non-null  float64
#  10  cb_person_cred_hist_length      45000 non-null  float64
#  11  credit_score                    45000 non-null  int64
# ...

# %% [markdown]
#  Data type of column 1- float
#  Data type of column 2- string
#  Data type of column 3- string
#  Data type of column 4- float
#  Data type of column 5- int
#  Data type of column 6- string
#  Data type of column 7- float
#  Data type of column 8- string
#  Data type of column 9- float
#  Data type of column 10- float
#  Data type of column 11- float
#  Data type of column 12- int
#  Data type of column 13- boolean
#  Data type of column 14- int

# %%
df['previous_loan_defaults_on_file'].dtype
# Out:
# dtype('O')

# %% [markdown]
# # 4.Use .describe() to get summary statistics of the numerical columns. What insights can you gather from this?

# %%
df.describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  45000.000000   4.500000e+04    45000.000000  45000.000000
# mean      27.764178   8.031905e+04        5.410333   9583.157556
# std        6.045108   8.042250e+04        6.063532   6314.886691
# min       20.000000   8.000000e+03        0.000000    500.000000
# 25%       24.000000   4.720400e+04        1.000000   5000.000000
# 50%       26.000000   6.704800e+04        4.000000   8000.000000
# 75%       30.000000   9.578925e+04        8.000000  12237.250000
# max      144.000000   7.200766e+06      125.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   45000.000000         45000.000000                45000.000000
# mean       11.006606             0.139725                    5.867489
# std         2.978808             0.087212                    3.879702
# min         5.420000             0.000000                    2.000000
# ...

# %% [markdown]
# # 5.Check the distribution of the target variable loan_status. Is the dataset balanced?

# %%
df['loan_status'].value_counts()
# Out:
# loan_status
# 0    35000
# 1    10000
# Name: count, dtype: int64

# %% [markdown]
# No the dataset is not balanced.

# %% [markdown]
# # Section 2: Data Visualization (From Simple to Complex)
# # 6. Plot the distribution of person_age. Is it normally distributed or skewed?

# %%
age_counts = df['person_age'].value_counts()
plt.bar(age_counts.index, age_counts.values)
plt.title('Age of account holders',fontsize=15)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.xticks(rotation=40)
plt.yticks(rotation=40)
plt.show()

#It is skewed.

# %% [markdown]
# # 7. Create a count plot for person_gender. Are there more males or females?

# %%
sns.countplot(x='person_gender', data=df)
plt.title('Distribution of person_gender')
plt.xlabel('Target Classes')
plt.ylabel('Count')
plt.show()

#There are more males than females.

# %% [markdown]
# # 8. Create a boxplot to compare loan_amnt across different loan_intent categories. What do you observe?

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(y='loan_amnt',x='loan_intent',data=df, patch_artist=True)
plt.title('Boxplot of loan_amnt', fontsize=16)
plt.ylabel('loan_amnt', fontsize=14)
plt.show()

# %% [markdown]
# # 9. Use a histogram or KDE plot to show the distribution of credit_score.

# %%
sns.histplot(df['credit_score'],bins=25,color='blue',kde= True)
plt.title('Histogram of credit_score',fontsize= 20)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.xticks(rotation=40)
plt.yticks(rotation=40)
plt.show()

# %% [markdown]
# # 10. Plot the average loan_int_rate for each loan_intent. Which intent has the highest average rate?

# %%
avg_rate = df.groupby('loan_intent')['loan_int_rate'].mean().reset_index()
plt.Figure(figsize=(10,12))
sns.barplot(y='loan_int_rate',x='loan_intent',color='blue', data= avg_rate)
plt.title('Bar plot of Highest Average RAte',fontsize= 20)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.xticks(rotation=20)
plt.yticks(rotation=20)
plt.show()

# %% [markdown]
# # 11. Use a violin plot to analyze how loan_amnt varies with loan_status.

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(y="loan_amnt", x="loan_status", data=df, palette="Set2")
plt.title("Distribution of loan amount by loan status")
plt.xlabel("Loan Status")
plt.ylabel("Loan amount")

plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_24500\3415618031.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(y="loan_amnt", x="loan_status", data=df, palette="Set2")

# %% [markdown]
# # 12. Create a bar plot to show the average person_income grouped by person_education level.

# %%
avg_rate = df.groupby('loan_intent')['loan_int_rate'].mean().reset_index()
plt.figure(figsize=(8, 6))
sns.barplot(y="person_income", x="person_education", data=df, order=sorted(df['person_education']))
plt.title("average person_income grouped by person_education level")
plt.xlabel("person_education ")
plt.ylabel("person_income ")
plt.show()

# %% [markdown]
# # 13. Create a heatmap to visualize the correlation between all numerical variables. Which features are most correlated with loan_status?

# %%
numerical_cols = df.select_dtypes(include=['float64', 'int64'])

corr_matrix = numerical_cols.corr()

plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Heatmap of Numerical Variables')
plt.show()

# %%
# Out:
# <Axes: xlabel='previous_loan_defaults_on_file', ylabel='count'>

# %% [markdown]
# # 14. Use a pairplot to explore relationships between person_income, loan_amnt, loan_percent_income, and loan_status. What trends do you see?

# %%
sns.pairplot(df, vars=['person_income', 'loan_amnt', 'loan_percent_income'], hue='loan_status', plot_kws={'alpha':0.5}, diag_kind='kde')
plt.suptitle('Pairplot of Income, Loan Amount, Loan Percent Income by Loan Status', y=1.02)
plt.show()

# %% [markdown]
# # Section 3: Encoding Categorical Variables

# %% [markdown]
# # 15. Which columns need encoding before applying machine learning models? Why?

# %% [markdown]
#  person_gender, person_education,
#  person_home_ownership, loan_intent, previous_loan_defaults_on_file needs encoding before applying machine learning models.

# %%
df['person_gender'] = df['person_gender'].map({'male': 1, 'female': 0})
df = pd.get_dummies(df, columns=['person_home_ownership'], drop_first=True, dtype='int')
df = pd.get_dummies(df, columns=['loan_intent'], drop_first=True, dtype='int')

# %%
edu_lvl = {
    'High School': 0,
    'Associate': 1,
    'Bachelor': 2,
    'Master': 3,
    'Doctorate': 4}
df['person_education'] = df['person_education'].replace(edu_lvl)
df
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_24500\3268349433.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['person_education'] = df['person_education'].replace(edu_lvl)
#        person_age  person_gender  person_education  person_income  \
# 0            22.0              0                 3        71948.0
# 1            21.0              0                 0        12282.0
# 2            25.0              0                 0        12438.0
# 3            23.0              0                 2        79753.0
# 4            24.0              1                 3        66135.0
# ...           ...            ...               ...            ...
# 44995        27.0              1                 1        47971.0
# ...

# %% [markdown]
# # 17. After encoding, how many total features does your dataset now have?

# %% [markdown]
# There are 20 features after encoding.

# %% [markdown]
# # Section 4: Correlation and Feature Analysis
# 18. Which numeric features have the highest positive or negative correlation with loan_status?

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])
correlation = numeric_df.corr()['loan_status'].drop('loan_status')
correlation.sort_values(ascending=False)
# Out:
# loan_percent_income               0.384880
# loan_int_rate                     0.332005
# loan_amnt                         0.107714
# credit_score                     -0.007647
# cb_person_cred_hist_length       -0.014851
# person_emp_exp                   -0.020481
# person_age                       -0.021476
# person_income                    -0.135808
# previous_loan_defaults_on_file   -0.543096
# Name: loan_status, dtype: float64

# %% [markdown]
#  Loan percent income has got the highest positive correlation with loan status.
#  Person income has got the highest negative correlation with loan status.

# %% [markdown]
# # 19. Does credit_score correlate strongly with loan_status? Is it positively or negatively correlated?

# %%
corr_valuecs = df['credit_score'].corr(df['loan_status'])
corr_valuecs
# Out:
# np.float64(-0.007647176334884977)

# %% [markdown]
# It is very very weak negatively correlated with loan status.

# %% [markdown]
# # 20. Does high loan_percent_income indicate higher chances of default (loan_status = 0)? What does the correlation matrix say?

# %%
corr_valuelpi = df['loan_percent_income'].corr(df['loan_status'])
corr_valuelpi
# Out:
# np.float64(0.38488037997204166)

# %% [markdown]
# High loan_percent_income does not indicate higher chances of default (loan_status = 0). high loan_percent_income have high chances of loan approval.

# %% [markdown]
# #  Section 5: Feature Scaling
# 22. Which features have vastly different ranges and may require scaling?

# %% [markdown]
# Features that have vastly different ranges and may require scaling
# person_age, person_income, loan_amnt, loan_int_rate, loan_percent_income, cb_person_cred_hist_length, credit_score, person_emp_exp

# %% [markdown]
# # 23. Apply MinMaxScaler or StandardScaler to relevant numerical features. Show before and after scaling plots.

# %%
num_features = ['person_age', 'person_income', 'loan_amnt', 'loan_int_rate',
                'loan_percent_income', 'cb_person_cred_hist_length',
                'credit_score', 'person_emp_exp']

plt.figure(figsize=(16, 8))

sns.histplot(df['person_age'], kde=True, ax=plt.subplot(2, 4, 1))
plt.title('Original person_age')

sns.histplot(df['person_income'], kde=True, ax=plt.subplot(2, 4, 2))
plt.title('Original person_income')

sns.histplot(df['loan_amnt'], kde=True, ax=plt.subplot(2, 4, 3))
plt.title('Original loan_amnt')

sns.histplot(df['loan_int_rate'], kde=True, ax=plt.subplot(2, 4, 4))
plt.title('Original loan_int_rate')

sns.histplot(df['loan_percent_income'], kde=True, ax=plt.subplot(2, 4, 5))
plt.title('Original loan_percent_income')

sns.histplot(df['cb_person_cred_hist_length'], kde=True, ax=plt.subplot(2, 4, 6))
plt.title('Original cb_person_cred_hist_length')

sns.histplot(df['credit_score'], kde=True, ax=plt.subplot(2, 4, 7))
plt.title('Original credit_score')

sns.histplot(df['person_emp_exp'], kde=True, ax=plt.subplot(2, 4, 8))
plt.title('Original person_emp_exp')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 24. Why is scaling important before applying algorithms like KNN or Logistic Regression?

# %% [markdown]
# Scaling helps make sure all features are treated fairly, so models like KNN and Logistic Regression work better and train faster.

# %% [markdown]
# # 25. Does scaling affect the distribution of data? How can you verify this visually?

# %% [markdown]
# Yes, scaling changes the scale but usually keeps the overall shape.

# %% [markdown]
# # Bonus: Preparing for Modeling
# 26. Based on your EDA and feature analysis, which features do you think are most important in predicting loan_status?

# %% [markdown]
# loan_percent_income 	0.384880
# loan_int_rate 	0.332005
# person_home_ownership_RENT 	0.255239
# loan_amnt 	0.107714
# person_income 	-0.135808
